# %%
# !pip install yfinance pandas numpy matplotlib statsmodels scipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import sys
import os
sys.path.append(os.path.abspath(".."))

# %%
from src.capm import run_sector_analysis, plot_beta_comparison, plot_security_line

stocks = [
    "ASIANPAINT.NS",
    "BERGEPAINT.NS",
    "SHALPAINTS.NS",
    "AKZOINDIA.NS",
    "KANSAINER.NS"
]

summary, results = run_sector_analysis(stocks)

summary
# Out:
#            Stock     Alpha      Beta  R_squared   White_p  Normality_p
# 0  ASIANPAINT.NS -0.010770  1.104558   0.307910  0.106532     0.833418
# 1  BERGEPAINT.NS -0.009452  0.928446   0.257045  0.609576     0.035168
# 2  SHALPAINTS.NS  0.008624  0.136057   0.002220  0.037853     0.453433
# 3   AKZOINDIA.NS  0.003781  0.425798   0.055990  0.061200     0.428478
# 4   KANSAINER.NS -0.014174  0.988137   0.206742  0.657442     0.517957

# %%
plot_beta_comparison(summary)

# %%
summary.to_csv("../results/capm_sector_results.csv", index=False)
